# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('..\data\StudentPerformanceFactors.csv')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# 50%             1.000000           3.000000    67.000000
# 75%             2.000000           4.000000    69.000000
# max             8.000000           6.000000   101.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
#  13  Peer_Influence              6607 non-null   object
#  14  Physical_Activity           6607 non-null   int64
#  15  Learning_Disabilities       6607 non-null   object
#  16  Parental_Education_Level    6517 non-null   object
#  17  Distance_from_Home          6540 non-null   object
#  18  Gender                      6607 non-null   object
#  19  Exam_Score                  6607 non-null   int64
# dtypes: int64(7), object(13)
# memory usage: 1.0+ MB

# %%
df.isnull().sum() * 100 / df.shape[0]
# Out:
# Hours_Studied                 0.000000
# Attendance                    0.000000
# Parental_Involvement          0.000000
# Access_to_Resources           0.000000
# Extracurricular_Activities    0.000000
# Sleep_Hours                   0.000000
# Previous_Scores               0.000000
# Motivation_Level              0.000000
# Internet_Access               0.000000
# Tutoring_Sessions             0.000000
# Family_Income                 0.000000
# Teacher_Quality               1.180566
# School_Type                   0.000000
# Peer_Influence                0.000000
# Physical_Activity             0.000000
# Learning_Disabilities         0.000000
# Parental_Education_Level      1.362192
# Distance_from_Home            1.014076
# Gender                        0.000000
# Exam_Score                    0.000000
# dtype: float64

# %%
### mapping null values in the database
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Fill null values

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0])
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0])
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(df['Distance_from_Home'].mode()[0])

# %%
### after filling
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Categorical Data visualization

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
for column in df.columns:
    sns.countplot(data = df, x = column)
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.catplot(data = df, x = "Sleep_Hours", y="Exam_Score", hue="Gender")

# %%
sns.catplot(data = df, x = "Distance_from_Home", y="Exam_Score", hue="Family_Income")

# %%
sns.countplot(data=df, x='Distance_from_Home', hue='Family_Income')
# Out:
# <Axes: xlabel='Distance_from_Home', ylabel='count'>

# %%
sns.countplot(data=df, x="Exam_Score", hue="Teacher_Quality", width=5.0)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df, x="Exam_Score", hue="Learning_Disabilities", width=5.0)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
sns.histplot(data=df, x="Attendance", hue="Family_Income",  multiple="stack")
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=df, x='Attendance', y="Exam_Score", hue="Family_Income")
plt.show()

# %%
cat_features =  df.select_dtypes(include=['object'])
num_features = df.select_dtypes(include=['number'])

# %%
sns.heatmap(num_features.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ## Encoding categorical variables

# %%
cat_features = pd.get_dummies(cat_features, drop_first=True)
cat_features
# Out:
#       Parental_Involvement_Low  Parental_Involvement_Medium  \
# 0                         True                        False
# 1                         True                        False
# 2                        False                         True
# 3                         True                        False
# 4                        False                         True
# ...                        ...                          ...
# 6602                     False                        False
# 6603                     False                        False
# 6604                     False                         True
# 6605                     False                        False
# 6606                     False                         True
#
#       Access_to_Resources_Low  Access_to_Resources_Medium  \
# 0                       False                       False
# 1                       False                        True
# 2                       False                        True
# 3                       False                        True
# 4                       False                        True
# ...                       ...                         ...
# 6602                    False                        True
# 6603                    False                        True
# 6604                     True                       False
# 6605                    False                       False
# 6606                     True                       False
#
#       Extracurricular_Activities_Yes  Motivation_Level_Low  \
# 0                              False                  True
# 1                              False                  True
# 2                               True                 False
# 3                               True                 False
# 4                               True                 False
# ...                              ...                   ...
# 6602                           False                 False
# 6603                           False                 False
# 6604                            True                  True
# 6605                            True                 False
# 6606                            True                 False
#
#       Motivation_Level_Medium  Internet_Access_Yes  Family_Income_Low  \
# 0                       False                 True               True
# 1                       False                 True              False
# 2                        True                 True              False
# 3                        True                 True              False
# 4                        True                 True              False
# ...                       ...                  ...                ...
# 6602                     True                 True              False
# 6603                     True                 True               True
# 6604                    False                 True               True
# 6605                    False                 True               True
# 6606                     True                 True              False
#
#       Family_Income_Medium  ...  Teacher_Quality_Medium  School_Type_Public  \
# 0                    False  ...                    True                True
# 1                     True  ...                    True                True
# 2                     True  ...                    True                True
# 3                     True  ...                    True                True
# 4                     True  ...                   False                True
# ...                    ...  ...                     ...                 ...
# 6602                 False  ...                    True                True
# 6603                 False  ...                   False                True
# 6604                 False  ...                    True                True
# 6605                 False  ...                    True               False
# 6606                  True  ...                    True                True
#
#       Peer_Influence_Neutral  Peer_Influence_Positive  \
# 0                      False                     True
# 1                      False                    False
# 2                       True                    False
# 3                      False                    False
# 4                       True                    False
# ...                      ...                      ...
# 6602                   False                     True
# 6603                   False                     True
# 6604                   False                    False
# 6605                   False                     True
# 6606                   False                     True
#
#       Learning_Disabilities_Yes  Parental_Education_Level_High School  \
# 0                         False                                  True
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                  True
# 4                         False                                 False
# ...                         ...                                   ...
# 6602                      False                                  True
# 6603                      False                                  True
# 6604                      False                                 False
# 6605                      False                                  True
# 6606                      False                                 False
#
#       Parental_Education_Level_Postgraduate  Distance_from_Home_Moderate  \
# 0                                     False                        False
# 1                                     False                         True
# 2                                      True                        False
# 3                                     False                         True
# 4                                     False                        False
# ...                                     ...                          ...
# 6602                                  False                        False
# 6603                                  False                        False
# 6604                                   True                        False
# 6605                                  False                        False
# 6606                                   True                        False
#
#       Distance_from_Home_Near  Gender_Male
# 0                        True         True
# 1                       False        False
# 2                        True         True
# 3                       False         True
# 4                        True        False
# ...                       ...          ...
# 6602                     True        False
# 6603                     True        False
# 6604                     True        False
# 6605                    False        False
# 6606                     True         True
#
# [6607 rows x 21 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)

encoder.fit(cat_features)
cat_features_encoded = pd.DataFrame(encoder.transform(cat_features), columns=encoder.get_feature_names_out(), index=cat_features.index)


sns.heatmap(cat_features_encoded.corr())
# Out:
# <Axes: >

# %%
x = pd.concat([num_features, cat_features_encoded], axis=1)

# %%
fig, ax = plt.subplots(figsize=(30, 20))
sns.heatmap(x.corr(), ax = ax, annot=True)
# Out:
# <Axes: >

# %%
x.corr()['Exam_Score'].sort_values(ascending=False)
# Out:
# Exam_Score                                     1.000000
# Attendance                                     0.581072
# Hours_Studied                                  0.445455
# Previous_Scores                                0.175079
# Tutoring_Sessions                              0.156525
# Access_to_Resources_Low_False                  0.132155
# Parental_Involvement_Low_False                 0.113602
# Parental_Education_Level_Postgraduate_True     0.093764
# Parental_Education_Level_High School_False     0.087054
# Learning_Disabilities_Yes_False                0.085066
# Family_Income_Low_False                        0.082025
# Peer_Influence_Positive_True                   0.081217
# Distance_from_Home_Near_True                   0.080933
# Motivation_Level_Low_False                     0.080039
# Extracurricular_Activities_Yes_True            0.064382
# Internet_Access_Yes_True                       0.051475
# Teacher_Quality_Medium_False                   0.043181
# Distance_from_Home_Moderate_False              0.043019
# Teacher_Quality_Low_False                      0.041192
# Parental_Involvement_Medium_False              0.035978
# Physical_Activity                              0.027824
# Access_to_Resources_Medium_False               0.026158
# Motivation_Level_Medium_True                   0.024771
# Family_Income_Medium_True                      0.020995
# School_Type_Public_False                       0.008844
# Peer_Influence_Neutral_False                   0.007795
# Gender_Male_False                              0.002032
# Gender_Male_True                              -0.002032
# Peer_Influence_Neutral_True                   -0.007795
# School_Type_Public_True                       -0.008844
# Sleep_Hours                                   -0.017022
# Family_Income_Medium_False                    -0.020995
# Motivation_Level_Medium_False                 -0.024771
# Access_to_Resources_Medium_True               -0.026158
# Parental_Involvement_Medium_True              -0.035978
# Teacher_Quality_Low_True                      -0.041192
# Distance_from_Home_Moderate_True              -0.043019
# Teacher_Quality_Medium_True                   -0.043181
# Internet_Access_Yes_False                     -0.051475
# Extracurricular_Activities_Yes_False          -0.064382
# Motivation_Level_Low_True                     -0.080039
# Distance_from_Home_Near_False                 -0.080933
# Peer_Influence_Positive_False                 -0.081217
# Family_Income_Low_True                        -0.082025
# Learning_Disabilities_Yes_True                -0.085066
# Parental_Education_Level_High School_True     -0.087054
# Parental_Education_Level_Postgraduate_False   -0.093764
# Parental_Involvement_Low_True                 -0.113602
# Access_to_Resources_Low_True                  -0.132155
# Name: Exam_Score, dtype: float64

# %%
for j,i in enumerate(x.corr()['Exam_Score']):
    if( i <= 0.99 and i >= 0.20) or (i <= -0.40 and i>= -0.99) :
        print(x.corr()['Exam_Score'].index[j])
# Out:
# Hours_Studied
# Attendance

# %% [markdown]
# ## Preparing model

# %%
y = df.iloc[:, -1]

X = df[['Hours_Studied', 'Attendance', 'Previous_Scores']]
# X= x.drop("Exam_Score", axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
import pickle

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

X
# Out:
# array([[ 0.50494151,  0.34837541, -0.14379993],
#        [-0.16282241, -1.38373605, -1.1161103 ],
#        [ 0.67188249,  1.56085343,  1.1063134 ],
#        ...,
#        [ 0.00411857,  0.86800885, -0.69940585],
#        [-1.66529123,  0.52158655,  1.1063134 ],
#        [-0.83058633, -1.12391933,  1.31466562]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)


print(model.score(X_test, y_test))
print("R^2 : ", round(r2_score(y_test,y_pred),2))
print("MAE : ", round(mean_absolute_error(y_test,y_pred),2))
print("RMSE : ", round(np.sqrt(mean_squared_error(y_test,y_pred)),2))

pickle.dump(model, open('../model/saved_model.pkl', 'bw'))
# Out:
# 0.7186619888411543
# R^2 :  0.72
# MAE :  1.4
# RMSE :  1.97

# %%
diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})

display(diff)
# Out:
#       Actual value  Predicted value
# 2726            73        71.911731
# 1260            67        66.548508
# 674             60        64.771279
# 634             63        65.638596
# 3109            66        68.217598
# ...            ...              ...
# 5831            72        69.674341
# 5557            67        67.742733
# 496             70        67.211752
# 3217            66        64.741565
# 3588            73        69.793558
#
# [661 rows x 2 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


x = X[:,0]
y = X[:,1]
z = X[:, 2]

ax.scatter(x, y, z)

A = np.vstack([x, y, np.ones_like(x)]).T
plane_coef, _, _, _ = np.linalg.lstsq(A, z, rcond=None)


x_plane, y_plane = np.meshgrid(x, y)
z_plane = plane_coef[0] * x_plane + plane_coef[1] * y_plane + plane_coef[2]

# %%
gb_model = GradientBoostingRegressor(random_state=42)

gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)

print("R^2 :       ", round(r2_score(y_test,y_pred_gb),2))
print("MAE :       ", round(mean_absolute_error(y_test,y_pred_gb),2))
print("RMSE :      ", round(np.sqrt(mean_squared_error(y_test,y_pred_gb)),2))
# Out:
# R^2 :        0.71
# MAE :        1.44
# RMSE :       2.0
